# %%
import sys
import os
import yaml
import ogbench

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)

from src.models.encoder import train_encoder

# %%
config_path = '../config/pointmaze/navigate/pointmaze_large_navigate.yaml'
base_config_path = '../config/base.yaml'
os.environ["MUJOCO_GL"] = "egl"

with open(config_path, 'r') as f:
    config = yaml.safe_load(f)
with open(base_config_path, 'r') as f:
    base_config = yaml.safe_load(f)

env, train_dataset, val_dataset = ogbench.make_env_and_datasets(config['env']['name'])

encoder = train_encoder(env, train_dataset, val_dataset, config, base_config)
# Out:
# Starting Encoder training on cuda
# Compiling value function with torch.compile...
# 100%|██████████| 10/10 [00:02<00:00,  3.40it/s]
# Training complete. Model saved to /sonic_home/luizfacury/LEGS/outputs/pointmaze_navigate/large/encoder/encoder_final.pth
# Generating training graphs

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Unable to determine the device handle for GPU0: 0000:08:00.0: Unknown Error
# No devices were found
